# %% [markdown]
# # Machine Learning: Supervised Classification

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import (confusion_matrix, precision_score,accuracy_score,
                            recall_score,mean_squared_error,roc_curve, auc)
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# We Use the Cumulative Database of Objects of Interest of the Kepler Exoplanet Observatory at https://exoplanetarchive.ipac.caltech.edu/docs/data.html
#
# In this notebook we use several classifiers in order to reproduce de disposition of the observed object among the classes CONFIRMED and FALSE POSITIVE.

# %%
# Load the exoplanet database
data_url = "https://exoplanetarchive.ipac.caltech.edu/cgi-bin/nstedAPI/nph-nstedAPI?table=cumulative&select=kepid,kepoi_name,koi_disposition,koi_period,koi_time0bk,koi_impact,koi_duration,koi_depth,koi_prad,koi_sma,koi_teq,koi_insol,koi_model_snr,koi_steff,koi_slogg,koi_srad,koi_smass,ra,dec,koi_kepmag&format=csv"
df_kepler = pd.read_csv(data_url)

# %% [markdown]
# Drop All NaNs

# %%
df_kepler_clean=df_kepler.dropna().reset_index(drop=True)
df_kepler_clean
# Out:
#          kepid kepoi_name koi_disposition  koi_period  koi_time0bk  \
# 0     10797460  K00752.01       CONFIRMED    9.488036   170.538750
# 1     10797460  K00752.02       CONFIRMED   54.418383   162.513840
# 2     10811496  K00753.01       CANDIDATE   19.899140   175.850252
# 3     10848459  K00754.01  FALSE POSITIVE    1.736952   170.307565
# 4     10854555  K00755.01       CONFIRMED    2.525592   171.595550
# ...        ...        ...             ...         ...          ...
# 9195  10090151  K07985.01  FALSE POSITIVE    0.527699   131.705093
# 9196  10128825  K07986.01       CANDIDATE    1.739849   133.001270
# 9197  10147276  K07987.01  FALSE POSITIVE    0.681402   132.181750
# 9198  10155286  K07988.01       CANDIDATE  333.486169   153.615010
# 9199  10156110  K07989.01  FALSE POSITIVE    4.856035   135.993300
#
#       koi_impact  koi_duration  koi_depth  koi_prad  koi_sma  koi_teq  \
# 0          0.146       2.95750      615.8      2.26   0.0853    793.0
# 1          0.586       4.50700      874.8      2.83   0.2734    443.0
# 2          0.969       1.78220    10829.0     14.60   0.1419    638.0
# 3          1.276       2.40641     8079.2     33.46   0.0267   1395.0
# 4          0.701       1.65450      603.3      2.75   0.0374   1406.0
# ...          ...           ...        ...       ...      ...      ...
# 9195       1.252       3.22210     1579.2     29.35   0.0128   2088.0
# 9196       0.043       3.11400       48.5      0.72   0.0290   1608.0
# 9197       0.147       0.86500      103.6      1.07   0.0157   2218.0
# 9198       0.214       3.19900      639.1     19.30   1.2233    557.0
# 9199       0.134       3.07800       76.7      1.05   0.0606   1266.0
#
#       koi_insol  koi_model_snr  koi_steff  koi_slogg  koi_srad  koi_smass  \
# 0         93.59           35.8     5455.0      4.467     0.927      0.919
# 1          9.11           25.8     5455.0      4.467     0.927      0.919
# 2         39.30           76.3     5853.0      4.544     0.868      0.961
# 3        891.96          505.6     5805.0      4.564     0.791      0.836
# 4        926.16           40.9     6031.0      4.438     1.046      1.095
# ...         ...            ...        ...        ...       ...        ...
# 9195    4500.53          453.3     5638.0      4.529     0.903      1.005
# 9196    1585.81           10.6     6119.0      4.444     1.031      1.075
# 9197    5713.41           12.3     6173.0      4.447     1.041      1.104
# 9198      22.68           14.0     4989.0      2.992     7.824      2.190
# 9199     607.42            8.2     6469.0      4.385     1.193      1.260
#
#              ra        dec  koi_kepmag
# 0     291.93423  48.141651      15.347
# 1     291.93423  48.141651      15.347
# 2     297.00482  48.134129      15.436
# 3     285.53461  48.285210      15.597
# 4     288.75488  48.226200      15.509
# ...         ...        ...         ...
# 9195  297.18875  47.093819      14.082
# 9196  286.50937  47.163219      14.757
# 9197  294.16489  47.176281      15.385
# 9198  296.76288  47.145142      10.998
# 9199  297.00977  47.121021      14.826
#
# [9200 rows x 20 columns]

# %% [markdown]
# We keep only physical data of the observed object

# %%
df=df_kepler_clean.drop(['kepid', 'kepoi_name'], axis=1)

# %% [markdown]
# We take only information about the classes CONFIRMED and FALSE POSITIVE for the binary classification in order to obtain a model that can be used on the CANDIDATE class.

# %%
df=df[df['koi_disposition']!='CANDIDATE'].reset_index(drop=True)

# %%
df['koi_disposition'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# Encode the target variable

# %%
le=LabelEncoder()
df['koi_disposition']=le.fit_transform(df['koi_disposition'])

# %% [markdown]
# Identify the Independent and dependent variables and split into train and test sets

# %%
X=df.drop('koi_disposition',axis=1).values
y=df['koi_disposition'].values
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
scaler=StandardScaler()
X_train_scaled_1=scaler.fit_transform(X_train)
X_test_scaled_1=scaler.transform(X_test)

# %% [markdown]
# ## Logistic Regression

# %%
lr=LogisticRegression()
lr.fit(X_train_scaled_1,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Crossed Validation

# %%
scores_1=cross_val_score(lr,X_train_scaled_1,y_train)
print(f'Logistic Regression Score = {scores_1.mean()} +/- {scores_1.std()}')
# Out:
# Logistic Regression Score = 0.8483595655487803 +/- 0.0035708040417453944

# %%
y_predict_1=lr.predict(X_test_scaled_1)

# %% [markdown]
# Confusion Matrix

# %%
class_names=[0,0]
fig,ax=plt.subplots(figsize=(3,3))
tick_marks=(np.arange(len(class_names)))
plt.xticks(tick_marks,class_names)
plt.yticks(tick_marks,class_names)
sns.heatmap(pd.DataFrame(confusion_matrix(y_test,y_predict_1)),annot=True,
            cmap='Blues',fmt='g',cbar=False,
            annot_kws={'size':20})
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.ylabel('True Disposition', fontsize=15,y=0.5)
plt.xlabel('Model Prediction', fontsize=15)
plt.show()

# %% [markdown]
# Metrics

# %%
print(f'Precision: {precision_score(y_test,y_predict_1)}')
print(f'Accuracy: {accuracy_score(y_test,y_predict_1)}')
print(f'Recall: {recall_score(y_test,y_predict_1)}')
# Out:
# Precision: 0.9068702290076336
# Accuracy: 0.8387978142076503
# Recall: 0.8366197183098592

# %% [markdown]
# ### ROC Curve

# %%
y_pred_prob_1=lr.predict_proba(X_test_scaled_1)
fpr,tpr,_=roc_curve(y_test,y_pred_prob_1[:,1])
roc_auc=auc(fpr,tpr)

# %%
plt.figure()
plt.plot(fpr,tpr,color='darkorange', label='ROC Curve (Area= %0.2f)'% roc_auc)
plt.plot([0,1],[0,1], color='navy',linestyle='--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## Logistic Regression with Second Order Polinomial Fit

# %%
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# Preprocessing

# %%
poly_2=PolynomialFeatures(degree=2)
X_train_2=poly_2.fit_transform(X_train)
X_test_2=poly_2.transform(X_test)

# %% [markdown]
# Scaling

# %%
X_train_scaled_2=scaler.fit_transform(X_train_2)
X_test_scaled_2=scaler.fit_transform(X_test_2)

# %% [markdown]
# Logistic Regression

# %%
lr_2=LogisticRegression(max_iter=1000)
lr_2.fit(X_train_scaled_2,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# Crossed Validation

# %%
scores_2=cross_val_score(lr_2,X_train_scaled_2,y_train)
print(f'Logistic Regression Score = {scores_2.mean()} +/- {scores_2.std()}')
# Out:
# Logistic Regression Score = 0.8702139862804877 +/- 0.012923630939410943

# %%
y_predict_2=lr_2.predict(X_test_scaled_2)

# %% [markdown]
# Confusion Matrix

# %%
class_names=[0,0]
fig,ax=plt.subplots(figsize=(3,3))
tick_marks=(np.arange(len(class_names)))
plt.xticks(tick_marks,class_names)
plt.yticks(tick_marks,class_names)
sns.heatmap(pd.DataFrame(confusion_matrix(y_test,y_predict_2)),annot=True,
            cmap='Blues',fmt='g',cbar=False,
            annot_kws={'size':20})
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.ylabel('True Disposition', fontsize=15,y=0.5)
plt.xlabel('Model Prediction', fontsize=15)
plt.show()

# %% [markdown]
# Metrics

# %%
print(f'Precision: {precision_score(y_test,y_predict_2)}')
print(f'Accuracy: {accuracy_score(y_test,y_predict_2)}')
print(f'Recall: {recall_score(y_test,y_predict_2)}')
# Out:
# Precision: 0.9581589958158996
# Accuracy: 0.8520036429872495
# Recall: 0.8063380281690141

# %% [markdown]
# ## Logistic Regression with Third Order Polinomial Fit

# %% [markdown]
# Preprocessing

# %%
poly_3=PolynomialFeatures(degree=3)
X_train_3=poly_3.fit_transform(X_train)
X_test_3=poly_3.transform(X_test)

# %% [markdown]
# Scaling

# %%
X_train_scaled_3=scaler.fit_transform(X_train_3)
X_test_scaled_3=scaler.fit_transform(X_test_3)

# %% [markdown]
# Logistic Regression

# %%
lr_3=LogisticRegression(max_iter=1000)
lr_3.fit(X_train_scaled_3,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# Crossed Validation

# %%
scores_3=cross_val_score(lr_3,X_train_scaled_3,y_train)
print(f'Logistic Regression Score = {scores_3.mean()} +/- {scores_3.std()}')
# Out:
# Logistic Regression Score = 0.883094512195122 +/- 0.013431011344447666

# %%
y_predict_3=lr_3.predict(X_test_scaled_3)

# %% [markdown]
# Confusion Matrix

# %%
class_names=[0,0]
fig,ax=plt.subplots(figsize=(3,3))
tick_marks=(np.arange(len(class_names)))
plt.xticks(tick_marks,class_names)
plt.yticks(tick_marks,class_names)
sns.heatmap(pd.DataFrame(confusion_matrix(y_test,y_predict_3)),annot=True,
            cmap='Blues',fmt='g',cbar=False,
            annot_kws={'size':20})
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.ylabel('True Disposition', fontsize=15,y=0.5)
plt.xlabel('Model Prediction', fontsize=15)
plt.show()

# %% [markdown]
# Metrics

# %%
print(f'Precision: {precision_score(y_test,y_predict_3)}')
print(f'Accuracy: {accuracy_score(y_test,y_predict_3)}')
print(f'Recall: {recall_score(y_test,y_predict_3)}')
# Out:
# Precision: 0.9726872246696036
# Accuracy: 0.8419854280510018
# Recall: 0.7774647887323943

# %% [markdown]
# ## Naïve Bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb=GaussianNB()
nb.fit(X_train_scaled_1,y_train)
# Out:
# GaussianNB()

# %% [markdown]
# Crossed Validation

# %%
scores_nb=cross_val_score(nb,X_train_scaled_1,y_train)
print(f'Naïve Bayes Score = {scores_nb.mean()} +/- {scores_nb.std()}')
# Out:
# Naïve Bayes Score = 0.7511676829268292 +/- 0.011167111525969131

# %%
y_predict_nb=nb.predict(X_test_scaled_1)

# %% [markdown]
# Confusion Matrix

# %%
class_names=[0,0]
fig,ax=plt.subplots(figsize=(3,3))
tick_marks=(np.arange(len(class_names)))
plt.xticks(tick_marks,class_names)
plt.yticks(tick_marks,class_names)
sns.heatmap(pd.DataFrame(confusion_matrix(y_test,y_predict_nb)),annot=True,
            cmap='Blues',fmt='g',cbar=False,
            annot_kws={'size':20})
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.ylabel('True Disposition', fontsize=15,y=0.5)
plt.xlabel('Model Prediction', fontsize=15)
plt.show()

# %% [markdown]
# Metrics

# %%
print(f'Precision: {precision_score(y_test,y_predict_nb)}')
print(f'Accuracy: {accuracy_score(y_test,y_predict_nb)}')
print(f'Recall: {recall_score(y_test,y_predict_nb)}')
# Out:
# Precision: 0.9679266895761741
# Accuracy: 0.7254098360655737
# Recall: 0.5950704225352113

# %% [markdown]
# ## Stochastic Gradient Descent Classifier

# %%
from sklearn.linear_model import SGDClassifier

# %%
sg=SGDClassifier()
sg.fit(X_train_scaled_1,y_train)
# Out:
# SGDClassifier()

# %% [markdown]
# Crossed Validation

# %%
scores_sg=cross_val_score(sg,X_train_scaled_1,y_train)
print(f'Stochastic Gradient Descent Score = {scores_sg.mean()} +/- {scores_sg.std()}')
# Out:
# Stochastic Gradient Descent Score = 0.843478849085366 +/- 0.007609926194418548

# %%
y_predict_sg=sg.predict(X_test_scaled_1)

# %% [markdown]
# Confusion Matrix

# %%
class_names=[0,0]
fig,ax=plt.subplots(figsize=(3,3))
tick_marks=(np.arange(len(class_names)))
plt.xticks(tick_marks,class_names)
plt.yticks(tick_marks,class_names)
sns.heatmap(pd.DataFrame(confusion_matrix(y_test,y_predict_sg)),annot=True,
            cmap='Blues',fmt='g',cbar=False,
            annot_kws={'size':20})
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.ylabel('True Disposition', fontsize=15,y=0.5)
plt.xlabel('Model Prediction', fontsize=15)
plt.show()

# %% [markdown]
# Metrics

# %%
print(f'Precision: {precision_score(y_test,y_predict_sg)}')
print(f'Accuracy: {accuracy_score(y_test,y_predict_sg)}')
print(f'Recall: {recall_score(y_test,y_predict_sg)}')
# Out:
# Precision: 0.9271089271089271
# Accuracy: 0.8283242258652095
# Recall: 0.7971830985915493

# %% [markdown]
# ## Support Vector Machine

# %%
from sklearn.svm import SVC

# %%
sv=SVC()
sv.fit(X_train_scaled_1,y_train)
# Out:
# SVC()

# %% [markdown]
# Crossed Validation

# %%
scores_sv=cross_val_score(sv,X_train_scaled_1,y_train)
print(f'SVM Score = {scores_sv.mean()} +/- {scores_sv.std()}')
# Out:
# SVM Score = 0.8546027057926828 +/- 0.00982586779914403

# %%
y_predict_sv=sv.predict(X_test_scaled_1)

# %% [markdown]
# Confusion Matrix

# %%
class_names=[0,0]
fig,ax=plt.subplots(figsize=(3,3))
tick_marks=(np.arange(len(class_names)))
plt.xticks(tick_marks,class_names)
plt.yticks(tick_marks,class_names)
sns.heatmap(pd.DataFrame(confusion_matrix(y_test,y_predict_sv)),annot=True,
            cmap='Blues',fmt='g',cbar=False,
            annot_kws={'size':20})
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.ylabel('True Disposition', fontsize=15,y=0.5)
plt.xlabel('Model Prediction', fontsize=15)
plt.show()

# %% [markdown]
# Metrics

# %%
print(f'Precision: {precision_score(y_test,y_predict_sv)}')
print(f'Accuracy: {accuracy_score(y_test,y_predict_sv)}')
print(f'Recall: {recall_score(y_test,y_predict_sv)}')
# Out:
# Precision: 0.9296325254104769
# Accuracy: 0.8538251366120219
# Recall: 0.8373239436619718

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()
dt.fit(X_train_scaled_1,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# Crossed Validation

# %%
scores_dt=cross_val_score(dt,X_train_scaled_1,y_train)
print(f'Decision Tree Score = {scores_dt.mean()} +/- {scores_dt.std()}')
# Out:
# Decision Tree Score = 0.8727543826219513 +/- 0.009347342837904381

# %%
y_predict_dt=sv.predict(X_test_scaled_1)

# %% [markdown]
# Confusion Matrix

# %%
class_names=[0,0]
fig,ax=plt.subplots(figsize=(3,3))
tick_marks=(np.arange(len(class_names)))
plt.xticks(tick_marks,class_names)
plt.yticks(tick_marks,class_names)
sns.heatmap(pd.DataFrame(confusion_matrix(y_test,y_predict_dt)),annot=True,
            cmap='Blues',fmt='g',cbar=False,
            annot_kws={'size':20})
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.ylabel('True Disposition', fontsize=15,y=0.5)
plt.xlabel('Model Prediction', fontsize=15)
plt.show()

# %% [markdown]
# Metrics

# %%
print(f'Precision: {precision_score(y_test,y_predict_dt)}')
print(f'Accuracy: {accuracy_score(y_test,y_predict_dt)}')
print(f'Recall: {recall_score(y_test,y_predict_dt)}')
# Out:
# Precision: 0.9296325254104769
# Accuracy: 0.8538251366120219
# Recall: 0.8373239436619718

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier(n_estimators=1000,random_state=10)
rf.fit(X_train_scaled_1,y_train)
# Out:
# RandomForestClassifier(n_estimators=1000, random_state=10)

# %% [markdown]
# Crossed Validation

# %%
scores_rf=cross_val_score(rf,X_train_scaled_1,y_train)
print(f'Random Forest Score = {scores_rf.mean()} +/- {scores_rf.std()}')
# Out:
# Random Forest Score = 0.9162759146341465 +/- 0.006095555310383085

# %%
y_predict_rf=rf.predict(X_test_scaled_1)

# %% [markdown]
# Confusion Matrix

# %%
class_names=[0,0]
fig,ax=plt.subplots(figsize=(3,3))
tick_marks=(np.arange(len(class_names)))
plt.xticks(tick_marks,class_names)
plt.yticks(tick_marks,class_names)
sns.heatmap(pd.DataFrame(confusion_matrix(y_test,y_predict_rf)),annot=True,
            cmap='Blues',fmt='g',cbar=False,
            annot_kws={'size':20})
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.ylabel('True Disposition', fontsize=15,y=0.5)
plt.xlabel('Model Prediction', fontsize=15)
plt.show()

# %% [markdown]
# Metrics

# %%
print(f'Precision: {precision_score(y_test,y_predict_rf)}')
print(f'Accuracy: {accuracy_score(y_test,y_predict_rf)}')
print(f'Recall: {recall_score(y_test,y_predict_rf)}')
# Out:
# Precision: 0.9451957295373665
# Accuracy: 0.9230418943533698
# Recall: 0.9352112676056338

# %% [markdown]
# ## Multi-layer Perceptron classifier

# %%
from sklearn.neural_network import MLPClassifier

# %%
mlp=MLPClassifier(hidden_layer_sizes=(16,8),
                  max_iter=20000,
                  activation='logistic',
                  tol=1e-7)
mlp.fit(X_train_scaled_1,y_train)
# Out:
# MLPClassifier(activation='logistic', hidden_layer_sizes=(16, 8), max_iter=20000,
#               tol=1e-07)

# %% [markdown]
# Crossed Validation

# %%
scores_mlp=cross_val_score(mlp,X_train_scaled_1,y_train)
print(f'Multi-layer Perceptron Score = {scores_mlp.mean()} +/- {scores_mlp.std()}')
# Out:
# Multi-layer Perceptron Score = 0.8895358231707317 +/- 0.010191832060688206

# %%
y_predict_mlp=mlp.predict(X_test_scaled_1)

# %% [markdown]
# Confusion Matrix

# %%
class_names=[0,0]
fig,ax=plt.subplots(figsize=(3,3))
tick_marks=(np.arange(len(class_names)))
plt.xticks(tick_marks,class_names)
plt.yticks(tick_marks,class_names)
sns.heatmap(pd.DataFrame(confusion_matrix(y_test,y_predict_mlp)),annot=True,
            cmap='Blues',fmt='g',cbar=False,
            annot_kws={'size':20})
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.ylabel('True Disposition', fontsize=15,y=0.5)
plt.xlabel('Model Prediction', fontsize=15)
plt.show()

# %% [markdown]
# Metrics

# %%
print(f'Precision: {precision_score(y_test,y_predict_mlp)}')
print(f'Accuracy: {accuracy_score(y_test,y_predict_mlp)}')
print(f'Recall: {recall_score(y_test,y_predict_mlp)}')
# Out:
# Precision: 0.9311094996374184
# Accuracy: 0.894808743169399
# Recall: 0.9042253521126761

# %% [markdown]
# # Artificial Neural Network

# %% [markdown]
# Network Architecture

# %%
model=Sequential()
model.add(Dense(32,input_shape=(X_train_scaled_1.shape[1],),activation='relu'))
model.add(Dense(16,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %% [markdown]
# Compile the Model

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %% [markdown]
# Train the Model

# %%
history=model.fit(X_train_scaled_1,y_train,epochs=100, verbose=True,
                  validation_split=0.1)
# Out:
# Epoch 1/100
# 145/145 [==============================] - 3s 6ms/step - loss: 0.5106 - accuracy: 0.7311 - val_loss: 0.4209 - val_accuracy: 0.8207
# Epoch 2/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.3922 - accuracy: 0.8269 - val_loss: 0.3619 - val_accuracy: 0.8499
# Epoch 3/100
# 145/145 [==============================] - 1s 4ms/step - loss: 0.3547 - accuracy: 0.8454 - val_loss: 0.3382 - val_accuracy: 0.8441
# Epoch 4/100
# 145/145 [==============================] - 1s 3ms/step - loss: 0.3354 - accuracy: 0.8551 - val_loss: 0.3324 - val_accuracy: 0.8616
# Epoch 5/100
# 145/145 [==============================] - 1s 4ms/step - loss: 0.3213 - accuracy: 0.8612 - val_loss: 0.3206 - val_accuracy: 0.8596
# Epoch 6/100
# 145/145 [==============================] - 1s 4ms/step - loss: 0.3113 - accuracy: 0.8636 - val_loss: 0.3179 - val_accuracy: 0.8577
# Epoch 7/100
# 145/145 [==============================] - 1s 4ms/step - loss: 0.3013 - accuracy: 0.8712 - val_loss: 0.3141 - val_accuracy: 0.8538
# Epoch 8/100
# 145/145 [==============================] - 1s 5ms/step - loss: 0.2933 - accuracy: 0.8749 - val_loss: 0.3123 - val_accuracy: 0.8596
# Epoch 9/100
# 145/145 [==============================] - 1s 6ms/step - loss: 0.2874 - accuracy: 0.8762 - val_loss: 0.3060 - val_accuracy: 0.8596
# Epoch 10/100
# 145/145 [==============================] - 1s 6ms/step - loss: 0.2830 - accuracy: 0.8779 - val_loss: 0.2999 - val_accuracy: 0.8616
# Epoch 11/100
# 145/145 [==============================] - 1s 5ms/step - loss: 0.2771 - accuracy: 0.8835 - val_loss: 0.2947 - val_accuracy: 0.8655
# Epoch 12/100
# 145/145 [==============================] - 1s 5ms/step - loss: 0.2738 - accuracy: 0.8829 - val_loss: 0.3082 - val_accuracy: 0.8577
# Epoch 13/100
# 145/145 [==============================] - 1s 4ms/step - loss: 0.2700 - accuracy: 0.8864 - val_loss: 0.2960 - val_accuracy: 0.8655
# Epoch 14/100
# 145/145 [==============================] - 1s 4ms/step - loss: 0.2663 - accuracy: 0.8877 - val_loss: 0.2882 - val_accuracy: 0.8655
# Epoch 15/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.2632 - accuracy: 0.8894 - val_loss: 0.2864 - val_accuracy: 0.8635
# Epoch 16/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.2611 - accuracy: 0.8887 - val_loss: 0.2898 - val_accuracy: 0.8674
# Epoch 17/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.2579 - accuracy: 0.8926 - val_loss: 0.2885 - val_accuracy: 0.8674
# Epoch 18/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.2544 - accuracy: 0.8937 - val_loss: 0.2851 - val_accuracy: 0.8635
# Epoch 19/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.2568 - accuracy: 0.8935 - val_loss: 0.2790 - val_accuracy: 0.8713
# Epoch 20/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.2517 - accuracy: 0.8959 - val_loss: 0.2937 - val_accuracy: 0.8577
# Epoch 21/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.2492 - accuracy: 0.8946 - val_loss: 0.2793 - val_accuracy: 0.8713
# Epoch 22/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.2459 - accuracy: 0.8985 - val_loss: 0.2888 - val_accuracy: 0.8713
# Epoch 23/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.2454 - accuracy: 0.8987 - val_loss: 0.2735 - val_accuracy: 0.8772
# Epoch 24/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.2437 - accuracy: 0.8968 - val_loss: 0.2778 - val_accuracy: 0.8674
# Epoch 25/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.2416 - accuracy: 0.8979 - val_loss: 0.2762 - val_accuracy: 0.8694
# Epoch 26/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.2400 - accuracy: 0.8983 - val_loss: 0.2728 - val_accuracy: 0.8733
# Epoch 27/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.2374 - accuracy: 0.9005 - val_loss: 0.2669 - val_accuracy: 0.8752
# Epoch 28/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.2349 - accuracy: 0.9037 - val_loss: 0.2676 - val_accuracy: 0.8733
# Epoch 29/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.2355 - accuracy: 0.9013 - val_loss: 0.2684 - val_accuracy: 0.8811
# Epoch 30/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.2311 - accuracy: 0.9054 - val_loss: 0.2783 - val_accuracy: 0.8772
# Epoch 31/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.2314 - accuracy: 0.9054 - val_loss: 0.2711 - val_accuracy: 0.8752
# Epoch 32/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.2315 - accuracy: 0.9054 - val_loss: 0.2646 - val_accuracy: 0.8850
# Epoch 33/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.2283 - accuracy: 0.9041 - val_loss: 0.2583 - val_accuracy: 0.8791
# Epoch 34/100
# 145/145 [==============================] - 1s 4ms/step - loss: 0.2267 - accuracy: 0.9098 - val_loss: 0.2611 - val_accuracy: 0.8811
# Epoch 35/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.2245 - accuracy: 0.9098 - val_loss: 0.2700 - val_accuracy: 0.8733
# Epoch 36/100
# 145/145 [==============================] - 1s 4ms/step - loss: 0.2256 - accuracy: 0.9065 - val_loss: 0.2740 - val_accuracy: 0.8772
# Epoch 37/100
# 145/145 [==============================] - 1s 4ms/step - loss: 0.2216 - accuracy: 0.9089 - val_loss: 0.2593 - val_accuracy: 0.8772
# Epoch 38/100
# 145/145 [==============================] - 1s 3ms/step - loss: 0.2206 - accuracy: 0.9102 - val_loss: 0.2576 - val_accuracy: 0.8869
# Epoch 39/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.2202 - accuracy: 0.9111 - val_loss: 0.2583 - val_accuracy: 0.8811
# Epoch 40/100
# 145/145 [==============================] - 1s 4ms/step - loss: 0.2191 - accuracy: 0.9100 - val_loss: 0.2572 - val_accuracy: 0.8830
# Epoch 41/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.2187 - accuracy: 0.9117 - val_loss: 0.2563 - val_accuracy: 0.8869
# Epoch 42/100
# 145/145 [==============================] - 1s 3ms/step - loss: 0.2181 - accuracy: 0.9113 - val_loss: 0.2676 - val_accuracy: 0.8733
# Epoch 43/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.2158 - accuracy: 0.9130 - val_loss: 0.2591 - val_accuracy: 0.8811
# Epoch 44/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.2169 - accuracy: 0.9115 - val_loss: 0.2539 - val_accuracy: 0.8908
# Epoch 45/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.2134 - accuracy: 0.9146 - val_loss: 0.2559 - val_accuracy: 0.8850
# Epoch 46/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.2138 - accuracy: 0.9130 - val_loss: 0.2544 - val_accuracy: 0.8791
# Epoch 47/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.2111 - accuracy: 0.9122 - val_loss: 0.2544 - val_accuracy: 0.8850
# Epoch 48/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.2127 - accuracy: 0.9139 - val_loss: 0.2499 - val_accuracy: 0.8928
# Epoch 49/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.2120 - accuracy: 0.9172 - val_loss: 0.2531 - val_accuracy: 0.8908
# Epoch 50/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.2100 - accuracy: 0.9156 - val_loss: 0.2474 - val_accuracy: 0.8967
# Epoch 51/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.2080 - accuracy: 0.9159 - val_loss: 0.2497 - val_accuracy: 0.8908
# Epoch 52/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.2082 - accuracy: 0.9165 - val_loss: 0.2499 - val_accuracy: 0.8947
# Epoch 53/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.2071 - accuracy: 0.9176 - val_loss: 0.2544 - val_accuracy: 0.8908
# Epoch 54/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.2054 - accuracy: 0.9167 - val_loss: 0.2565 - val_accuracy: 0.8791
# Epoch 55/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.2066 - accuracy: 0.9143 - val_loss: 0.2545 - val_accuracy: 0.8908
# Epoch 56/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.2031 - accuracy: 0.9156 - val_loss: 0.2504 - val_accuracy: 0.8889
# Epoch 57/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.2070 - accuracy: 0.9130 - val_loss: 0.2694 - val_accuracy: 0.8830
# Epoch 58/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.2039 - accuracy: 0.9172 - val_loss: 0.2476 - val_accuracy: 0.8908
# Epoch 59/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.2037 - accuracy: 0.9167 - val_loss: 0.2545 - val_accuracy: 0.8869
# Epoch 60/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.2030 - accuracy: 0.9159 - val_loss: 0.2452 - val_accuracy: 0.8928
# Epoch 61/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.2001 - accuracy: 0.9195 - val_loss: 0.2541 - val_accuracy: 0.8967
# Epoch 62/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.2023 - accuracy: 0.9169 - val_loss: 0.2541 - val_accuracy: 0.8869
# Epoch 63/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.1995 - accuracy: 0.9195 - val_loss: 0.2550 - val_accuracy: 0.8947
# Epoch 64/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.1991 - accuracy: 0.9206 - val_loss: 0.2408 - val_accuracy: 0.8986
# Epoch 65/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.1995 - accuracy: 0.9187 - val_loss: 0.2541 - val_accuracy: 0.8908
# Epoch 66/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.1950 - accuracy: 0.9221 - val_loss: 0.2581 - val_accuracy: 0.8908
# Epoch 67/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.1991 - accuracy: 0.9204 - val_loss: 0.2581 - val_accuracy: 0.8869
# Epoch 68/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.1996 - accuracy: 0.9204 - val_loss: 0.2467 - val_accuracy: 0.8947
# Epoch 69/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.1963 - accuracy: 0.9200 - val_loss: 0.2428 - val_accuracy: 0.8947
# Epoch 70/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.1972 - accuracy: 0.9213 - val_loss: 0.2494 - val_accuracy: 0.8908
# Epoch 71/100
# 145/145 [==============================] - 1s 4ms/step - loss: 0.1945 - accuracy: 0.9204 - val_loss: 0.2426 - val_accuracy: 0.8947
# Epoch 72/100
# 145/145 [==============================] - 1s 4ms/step - loss: 0.1937 - accuracy: 0.9234 - val_loss: 0.2399 - val_accuracy: 0.8947
# Epoch 73/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.1934 - accuracy: 0.9217 - val_loss: 0.2457 - val_accuracy: 0.8928
# Epoch 74/100
# 145/145 [==============================] - 1s 3ms/step - loss: 0.1954 - accuracy: 0.9208 - val_loss: 0.2372 - val_accuracy: 0.9025
# Epoch 75/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.1921 - accuracy: 0.9230 - val_loss: 0.2407 - val_accuracy: 0.9025
# Epoch 76/100
# 145/145 [==============================] - 1s 4ms/step - loss: 0.1943 - accuracy: 0.9200 - val_loss: 0.2481 - val_accuracy: 0.8947
# Epoch 77/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.1912 - accuracy: 0.9230 - val_loss: 0.2449 - val_accuracy: 0.8967
# Epoch 78/100
# 145/145 [==============================] - 1s 4ms/step - loss: 0.1923 - accuracy: 0.9241 - val_loss: 0.2493 - val_accuracy: 0.8967
# Epoch 79/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.1924 - accuracy: 0.9224 - val_loss: 0.2449 - val_accuracy: 0.8947
# Epoch 80/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.1910 - accuracy: 0.9211 - val_loss: 0.2589 - val_accuracy: 0.8947
# Epoch 81/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.1905 - accuracy: 0.9213 - val_loss: 0.2376 - val_accuracy: 0.8928
# Epoch 82/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.1903 - accuracy: 0.9206 - val_loss: 0.2461 - val_accuracy: 0.8908
# Epoch 83/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.1921 - accuracy: 0.9234 - val_loss: 0.2465 - val_accuracy: 0.8967
# Epoch 84/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.1892 - accuracy: 0.9232 - val_loss: 0.2457 - val_accuracy: 0.8967
# Epoch 85/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.1891 - accuracy: 0.9224 - val_loss: 0.2502 - val_accuracy: 0.8967
# Epoch 86/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.1913 - accuracy: 0.9219 - val_loss: 0.2447 - val_accuracy: 0.8928
# Epoch 87/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.1906 - accuracy: 0.9234 - val_loss: 0.2471 - val_accuracy: 0.8986
# Epoch 88/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.1874 - accuracy: 0.9237 - val_loss: 0.2397 - val_accuracy: 0.8947
# Epoch 89/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.1870 - accuracy: 0.9243 - val_loss: 0.2720 - val_accuracy: 0.8889
# Epoch 90/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.1871 - accuracy: 0.9260 - val_loss: 0.2325 - val_accuracy: 0.9045
# Epoch 91/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.1862 - accuracy: 0.9250 - val_loss: 0.2408 - val_accuracy: 0.8986
# Epoch 92/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.1837 - accuracy: 0.9271 - val_loss: 0.2535 - val_accuracy: 0.8889
# Epoch 93/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.1864 - accuracy: 0.9234 - val_loss: 0.2470 - val_accuracy: 0.8947
# Epoch 94/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.1840 - accuracy: 0.9278 - val_loss: 0.2456 - val_accuracy: 0.8908
# Epoch 95/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.1836 - accuracy: 0.9263 - val_loss: 0.2468 - val_accuracy: 0.8908
# Epoch 96/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.1855 - accuracy: 0.9258 - val_loss: 0.2516 - val_accuracy: 0.8967
# Epoch 97/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.1849 - accuracy: 0.9265 - val_loss: 0.2568 - val_accuracy: 0.8986
# Epoch 98/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.1835 - accuracy: 0.9282 - val_loss: 0.2562 - val_accuracy: 0.8889
# Epoch 99/100
# 145/145 [==============================] - 0s 3ms/step - loss: 0.1825 - accuracy: 0.9252 - val_loss: 0.2437 - val_accuracy: 0.8947
# Epoch 100/100
# 145/145 [==============================] - 0s 2ms/step - loss: 0.1848 - accuracy: 0.9273 - val_loss: 0.2561 - val_accuracy: 0.8947

# %%
y_predict_model=model.predict(X_test_scaled_1)
# Out:
# 69/69 [==============================] - 0s 1ms/step

# %% [markdown]
# Confusion Matrix

# %%
class_names=[0,0]
fig,ax=plt.subplots(figsize=(3,3))
tick_marks=(np.arange(len(class_names)))
plt.xticks(tick_marks,class_names)
plt.yticks(tick_marks,class_names)
sns.heatmap(pd.DataFrame(confusion_matrix(y_test,y_predict_model.round())),
            annot=True,cmap='Blues',fmt='g',cbar=False,
            annot_kws={'size':20})
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.ylabel('True Disposition', fontsize=15,y=0.5)
plt.xlabel('Model Prediction', fontsize=15)
plt.show()

# %% [markdown]
# Metrics

# %%
print(f'Precision: {precision_score(y_test,y_predict_model.round())}')
print(f'Accuracy: {accuracy_score(y_test,y_predict_model.round())}')
print(f'Recall: {recall_score(y_test,y_predict_model.round())}')
# Out:
# Precision: 0.9401022644265887
# Accuracy: 0.9020947176684881
# Recall: 0.9063380281690141
