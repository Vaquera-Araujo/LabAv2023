# %% [markdown]
# # Klein-Gordon Field Equation of Motion

# %% [markdown]
# ##Preamble

# %%
from sympy import symbols, Rational, simplify
from sympy.tensor.tensor import tensor_heads,TensorIndexType,tensor_indices
from sympy.tensor.toperators import PartialDerivative

# %% [markdown]
# Definition of Indices

# %%
Lorentz = TensorIndexType('Lorentz', dummy_name='alpha')

# %%
mu, nu, rho, sigma = tensor_indices('mu, nu, rho, sigma ', Lorentz)

# %% [markdown]
# Metric tensor and Kronecker delta

# %%
g = Lorentz.metric
KD= Lorentz.delta

# %% [markdown]
# Definition of the Klein-Gordon field $\phi$, its derivative $\partial_\mu\phi\equiv d\phi(\mu)$ and its mass

# %%
x, d_phi= tensor_heads('x, d_phi', [Lorentz])
phi= tensor_heads('phi', [Lorentz]*0)
m=symbols('m')

# %% [markdown]
# ## Lagrangian Density
# $L=\frac{1}{2}\partial^\mu\phi\partial_\mu\phi-\frac{m^2}{2}\phi^2$

# %%
Lag=Rational(1,2)*d_phi(mu)*d_phi(-mu)-Rational(1,2)*m**2*phi()*phi()

# %% [markdown]
# ## Equation of motion
#
# $\partial^{\mu}\left[\frac{\partial L}{\partial(\partial^\mu\phi)}\right]-\frac{\partial{L}}{\partial{\phi}}=0$

# %%
def EOM_KG(L):
  #This function finds the equation of motion of a scalar field
  dummy = tensor_indices('dummy', Lorentz) # dummy index
  u=(PartialDerivative(L,phi())._perform_derivative()) # Partial derivative of L w.r.t. the scalar field
  v=((PartialDerivative(L.expand(),d_phi(-dummy))._perform_derivative()).contract_metric(g).contract_delta(KD))  # Partial derivative of L w.r.t. the  derivatives of the scalar field
  w=v.subs(d_phi(dummy),PartialDerivative(phi(),x(-dummy))) # replaces d_phi for the actual derivative
  return simplify(PartialDerivative(w,x(dummy))-u) # returns the equation of motion

# %%
EOM_KG(Lag)
# Out:
# PartialDerivative(phi, x(-alpha_0), x(alpha_0)) + m**2*phi
